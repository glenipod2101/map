# %%
import pandas as pd
import csv

# %%
path = "destinations.csv"

# %%
df = pd.read_csv(path, sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Moving From             266 non-null    object
#  1   Moving To               266 non-null    object
#  2   utm_source              31 non-null     object
#  3   utm_medium              31 non-null     object
#  4   utm_campaign            31 non-null     object
#  5   Submission ID           266 non-null    int64
#  6   Submission Create Date  266 non-null    object
#  7   Submission Status       266 non-null    object
#  8   Source URL              266 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 18.8+ KB

# %%
filtered_df = df[~((df['First Name'].str.contains('test', case=False, na=False)) |
                   (df['Last Name'].str.contains('test', case=False, na=False)) |
                   (df['Email'].str.contains('test', case=False, na=False)) |
                   df['First Name'].isna() | df['Last Name'].isna() | df['Email'].isna() |
                   df['Origin Address*'].isna() | df['Destination Address*'].isna())]

# Remove duplicates
filtered_df = filtered_df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hp EliteBook\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'First Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
filtered_df
# Out:
#       First Name  Last Name Phone Number                           Email  \
# 0       Savannah     Patlan   8182718154        savannahpatlan@yahoo.com
# 2         Amanda  Rodriguez   3105988437  amanda.rodriguez1313@gmail.com
# 3         Deanne    Ellison   8052172466            dosellison@gmail.com
# 4         Regina   Williams   9208892458           laregina717@gmail.com
# 5           Anna     Cutino   8186181703             elbagirls@yahoo.com
# ...          ...        ...          ...                             ...
# 11691   Isabella     Rivera   6315386665      isabellarivera45@gmail.com
# 11692       Rhys    Frazier   6038975621           frazierrhys@gmail.com
# 11695     Daniel     Pitner   4803782282        daniel@rotatedigital.com
# 11697     Daniel     Pitner   4803782282        daniel@rotatedigital.com
# 11701        ccc       cccc   2158892587                     ccc@rrr.wwq
#
#                                    Origin Address*  \
# ...

# %%
filtered_df.to_csv('filtered_forms.csv', index=False)

# %%
destinations
# Out:
#                                    Origin Address*  \
# 0                      11027 Sharp Ave, 91345-1732
# 2                    2084 Garden Lane APT B, 92627
# 3              1539 Via Brisa Del Lago, 92078-5272
# 4                         820 Cassanova Ave, 93940
# 5                           1570 Via Parque, 91360
# ...                                            ...
# 11691                           2443 FM 1488 #2444
# 11692           263 n chorro San Luis Obispo 93405
# 11695       2334 Perseus Ct, Bakersfield, CA 93308
# 11697  2000 Grand Lakes Ave, Bakersfield, CA 93311
# 11701                                        93504
#
#                               Destination Address* Submission Create Date
# 0                    24842 Newhall Ave, 91321-1526    2024-12-31 21:07:51
# 2                   18302 Patterson Ln, 92646-1686    2024-12-31 19:41:47
# 3              1509 Via Brisa Del Lago, 92078-5272    2024-12-31 18:37:49
# ...

# %%
destinations.to_csv('destinations.csv', index=False)
